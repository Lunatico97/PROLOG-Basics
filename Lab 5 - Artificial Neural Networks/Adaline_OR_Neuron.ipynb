# %% [markdown]
# # Adaline Learning for OR Neuron

# %%
import numpy as np ;

# %% [markdown]
# - Set up inputs and outputs of OR gate for training the neuron

# %%
inputs = [[0,0], [0,1], [1,0], [1,1]] ;
print('Inputs: ', inputs) ;
# Out:
# Inputs:  [[0, 0], [0, 1], [1, 0], [1, 1]]

# %%
outputs = np.zeros(len(inputs)) ;
for i in range(len(inputs)):
    if inputs[i][0] == 1 or inputs[i][1] == 1:
        outputs[i] = 1 ;
    else:
        outputs[i] = 0 ;
        
print('Target outputs: ', outputs) ;
# Out:
# Target outputs:  [0. 1. 1. 1.]

# %% [markdown]
# - Initialize weights to random values and select a learning rate

# %%
rate = 0.1 ;
tolerance = 0.0001 ;
np.random.seed(777) ;
weights = np.random.randn(2) ;
print('Initial weights: ', weights) ;
# Out:
# Initial weights:  [-0.46820879 -0.82282485]

# %%
bias = np.random.randn(1) ;
print('Initial Bias: ', bias) ;
# Out:
# Initial Bias:  [-0.0653801]

# %% [markdown]
# - Update the bias and weights using delta rule

# %%
j = 0 ;
switch = True ;
prev_ms_error = 0 ;
while switch:
    print('Epoch', (j+1)) ;
    print('-------------------------------------------------------------')
    ms_error = 0 ;
    for i in range(len(inputs)):
        u = np.dot(inputs[i], weights) + bias ;
        error = outputs[i] - u ;
        weights += rate * error * inputs[i] ;
        bias += rate * error ;
        ms_error += np.square(error) ;
        print('Weights: ', weights, 'Bias: ', bias) ;
    if np.abs(ms_error - prev_ms_error) < tolerance:
        switch = False ;
    prev_ms_error = ms_error ;
    print('MSE: ', ms_error) ;
    j += 1 ;
# Out:
# Epoch 1
# -------------------------------------------------------------
# Weights:  [-0.46820879 -0.82282485] Bias:  [-0.05884209]
# Weights:  [-0.46820879 -0.63465816] Bias:  [0.1293246]
# Weights:  [-0.33432037 -0.63465816] Bias:  [0.26321302]
# Weights:  [-0.16374382 -0.46408161] Bias:  [0.43378957]
# MSE:  [8.24719191]
# Epoch 2
# -------------------------------------------------------------
# Weights:  [-0.16374382 -0.46408161] Bias:  [0.39041062]
# Weights:  [-0.16374382 -0.35671451] Bias:  [0.49777771]
# Weights:  [-0.09714721 -0.35671451] Bias:  [0.56437433]
# Weights:  [-0.00819847 -0.26776577] Bias:  [0.65332307]
# MSE:  [2.57564148]
# Epoch 3
# -------------------------------------------------------------
# Weights:  [-0.00819847 -0.26776577] Bias:  [0.58799076]
# Weights:  [-0.00819847 -0.19978827] Bias:  [0.65596826]
# Weights:  [ 0.02702455 -0.19978827] Bias:  [0.69119128]
# Weights:  [ 0.07518179 -0.15163102] Bias:  [0.73934853]
# MSE:  [1.24490323]
# Epoch 4
# -------------------------------------------------------------
# Weights:  [ 0.07518179 -0.15163102] Bias:  [0.66541367]
# Weights:  [ 0.07518179 -0.10300929] Bias:  [0.71403541]
# Weights:  [ 0.09626007 -0.10300929] Bias:  [0.73511369]
# Weights:  [ 0.12342363 -0.07584574] Bias:  [0.76227724]
# MSE:  [0.9012588]
# Epoch 5
# -------------------------------------------------------------
# Weights:  [ 0.12342363 -0.07584574] Bias:  [0.68604952]
# Weights:  [ 0.12342363 -0.03686611] Bias:  [0.72502914]
# Weights:  [ 0.13857835 -0.03686611] Bias:  [0.74018386]
# Weights:  [ 0.15438874 -0.02105572] Bias:  [0.75599425]
# MSE:  [0.78097109]
# Epoch 6
# -------------------------------------------------------------
# Weights:  [ 0.15438874 -0.02105572] Bias:  [0.68039483]
# Weights:  [0.15438874 0.01301037] Bias:  [0.71446092]
# Weights:  [0.16750377 0.01301037] Bias:  [0.72757595]
# Weights:  [0.17669476 0.02220136] Bias:  [0.73676694]
# MSE:  [0.713225]
# Epoch 7
# -------------------------------------------------------------
# Weights:  [0.17669476 0.02220136] Bias:  [0.66309025]
# Weights:  [0.17669476 0.0536722 ] Bias:  [0.69456109]
# Weights:  [0.18956918 0.0536722 ] Bias:  [0.7074355]
# Weights:  [0.19450149 0.05860451] Bias:  [0.71236781]
# MSE:  [0.66087473]
# Epoch 8
# -------------------------------------------------------------
# Weights:  [0.19450149 0.05860451] Bias:  [0.64113103]
# Weights:  [0.19450149 0.08863095] Bias:  [0.67115748]
# Weights:  [0.20793559 0.08863095] Bias:  [0.68459158]
# Weights:  [0.20981978 0.09051514] Bias:  [0.68647577]
# MSE:  [0.61602918]
# Epoch 9
# -------------------------------------------------------------
# Weights:  [0.20981978 0.09051514] Bias:  [0.61782819]
# Weights:  [0.20981978 0.11968081] Bias:  [0.64699386]
# Weights:  [0.22413842 0.11968081] Bias:  [0.66131249]
# Weights:  [0.22362525 0.11916764] Bias:  [0.66079932]
# MSE:  [0.57684126]
# Epoch 10
# -------------------------------------------------------------
# Weights:  [0.22362525 0.11916764] Bias:  [0.59471939]
# Weights:  [0.22362525 0.14777893] Bias:  [0.62333069]
# Weights:  [0.23892965 0.14777893] Bias:  [0.63863509]
# Weights:  [0.23639528 0.14524457] Bias:  [0.63610073]
# MSE:  [0.54258117]
# Epoch 11
# -------------------------------------------------------------
# Weights:  [0.23639528 0.14524457] Bias:  [0.57249065]
# Weights:  [0.23639528 0.17347104] Bias:  [0.60071713]
# Weights:  [0.25268404 0.17347104] Bias:  [0.61700589]
# Weights:  [0.24836794 0.16915495] Bias:  [0.61268979]
# MSE:  [0.51269278]
# Epoch 12
# -------------------------------------------------------------
# Weights:  [0.24836794 0.16915495] Bias:  [0.55142081]
# Weights:  [0.24836794 0.19709737] Bias:  [0.57936324]
# Weights:  [0.26559483 0.19709737] Bias:  [0.59659012]
# Weights:  [0.25966659 0.19116914] Bias:  [0.59066189]
# MSE:  [0.48665763]
# Epoch 13
# -------------------------------------------------------------
# Weights:  [0.25966659 0.19116914] Bias:  [0.5315957]
# Weights:  [0.25966659 0.21889265] Bias:  [0.55931922]
# Weights:  [0.27776801 0.21889265] Bias:  [0.57742063]
# Weights:  [0.27035988 0.21148452] Bias:  [0.5700125]
# MSE:  [0.46399498]
# Epoch 14
# -------------------------------------------------------------
# Weights:  [0.27035988 0.21148452] Bias:  [0.51301125]
# Weights:  [0.27035988 0.23903495] Bias:  [0.54056168]
# Weights:  [0.28926773 0.23903495] Bias:  [0.55946952]
# Weights:  [0.28049051 0.23025773] Bias:  [0.5506923]
# MSE:  [0.44427145]
# Epoch 15
# -------------------------------------------------------------
# Weights:  [0.28049051 0.23025773] Bias:  [0.49562307]
# Weights:  [0.28049051 0.25766965] Bias:  [0.52303499]
# Weights:  [0.30013796 0.25766965] Bias:  [0.54268244]
# Weights:  [0.29008895 0.24762064] Bias:  [0.53263344]
# MSE:  [0.42710383]
# Epoch 16
# -------------------------------------------------------------
# Weights:  [0.29008895 0.24762064] Bias:  [0.47937009]
# Weights:  [0.29008895 0.27492157] Bias:  [0.50667102]
# Weights:  [0.31041296 0.27492157] Bias:  [0.52699502]
# Weights:  [0.29918    0.26368861] Bias:  [0.51576207]
# MSE:  [0.41215687]
# Epoch 17
# -------------------------------------------------------------
# Weights:  [0.29918    0.26368861] Bias:  [0.46418586]
# Weights:  [0.29918    0.29090117] Bias:  [0.49139841]
# Weights:  [0.32012216 0.29090117] Bias:  [0.51234057]
# Weights:  [0.30778577 0.27856478] Bias:  [0.50000418]
# MSE:  [0.39913886]
# Epoch 18
# -------------------------------------------------------------
# Weights:  [0.30778577 0.27856478] Bias:  [0.45000376]
# Weights:  [0.30778577 0.30570792] Bias:  [0.47714691]
# Weights:  [0.3292925  0.30570792] Bias:  [0.49865364]
# Weights:  [0.3159271  0.29234252] Bias:  [0.48528823]
# MSE:  [0.38779658]
# Epoch 19
# -------------------------------------------------------------
# Weights:  [0.3159271  0.29234252] Bias:  [0.43675941]
# Weights:  [0.3159271  0.31943232] Bias:  [0.46384922]
# Weights:  [0.33794946 0.31943232] Bias:  [0.48587159]
# Weights:  [0.32362413 0.30510699] Bias:  [0.47154625]
# MSE:  [0.37791044]
# Epoch 20
# -------------------------------------------------------------
# Weights:  [0.32362413 0.30510699] Bias:  [0.42439162]
# Weights:  [0.32362413 0.33215713] Bias:  [0.45144176]
# Weights:  [0.34611754 0.33215713] Bias:  [0.47393517]
# Weights:  [0.33089655 0.31693614] Bias:  [0.45871419]
# MSE:  [0.36929006]
# Epoch 21
# -------------------------------------------------------------
# Weights:  [0.33089655 0.31693614] Bias:  [0.41284277]
# Weights:  [0.33089655 0.34395825] Bias:  [0.43986488]
# Weights:  [0.35382041 0.34395825] Bias:  [0.46278874]
# Weights:  [0.33776367 0.32790151] Bias:  [0.446732]
# MSE:  [0.36177035]
# Epoch 22
# -------------------------------------------------------------
# Weights:  [0.33776367 0.32790151] Bias:  [0.4020588]
# Weights:  [0.33776367 0.35490548] Bias:  [0.42906277]
# Weights:  [0.36108103 0.35490548] Bias:  [0.45238012]
# Weights:  [0.34424436 0.33806882] Bias:  [0.43554346]
# MSE:  [0.35520814]
# Epoch 23
# -------------------------------------------------------------
# Weights:  [0.34424436 0.33806882] Bias:  [0.39198911]
# Weights:  [0.34424436 0.36506302] Bias:  [0.41898332]
# Weights:  [0.3679216  0.36506302] Bias:  [0.44266055]
# Weights:  [0.35035708 0.34749851] Bias:  [0.42509604]
# MSE:  [0.34947918]
# Epoch 24
# -------------------------------------------------------------
# Weights:  [0.35035708 0.34749851] Bias:  [0.38258643]
# Weights:  [0.35035708 0.37449001] Bias:  [0.40957794]
# Weights:  [0.37436358 0.37449001] Bias:  [0.43358444]
# Weights:  [0.35611977 0.35624621] Bias:  [0.41534063]
# MSE:  [0.34447561]
# Epoch 25
# -------------------------------------------------------------
# Weights:  [0.35611977 0.35624621] Bias:  [0.37380657]
# Weights:  [0.35611977 0.38324093] Bias:  [0.40080129]
# Weights:  [0.38042767 0.38324093] Bias:  [0.42510919]
# Weights:  [0.36154989 0.36436315] Bias:  [0.40623141]
# MSE:  [0.34010376]
# Epoch 26
# -------------------------------------------------------------
# Weights:  [0.36154989 0.36436315] Bias:  [0.36560827]
# Weights:  [0.36154989 0.39136601] Bias:  [0.39261112]
# Weights:  [0.38613379 0.39136601] Bias:  [0.41719502]
# Weights:  [0.36666431 0.37189653] Bias:  [0.39772554]
# MSE:  [0.33628227]
# Epoch 27
# -------------------------------------------------------------
# Weights:  [0.36666431 0.37189653] Bias:  [0.35795299]
# Weights:  [0.36666431 0.39891158] Bias:  [0.38496804]
# Weights:  [0.39150107 0.39891158] Bias:  [0.4098048]
# Weights:  [0.37147933 0.37888983] Bias:  [0.38978306]
# MSE:  [0.33294041]
# Epoch 28
# -------------------------------------------------------------
# Weights:  [0.37147933 0.37888983] Bias:  [0.35080475]
# Weights:  [0.37147933 0.40592037] Bias:  [0.37783529]
# Weights:  [0.39654786 0.40592037] Bias:  [0.40290383]
# Weights:  [0.37601066 0.38538317] Bias:  [0.38236662]
# MSE:  [0.3300167]
# Epoch 29
# -------------------------------------------------------------
# Weights:  [0.37601066 0.38538317] Bias:  [0.34412996]
# Weights:  [0.37601066 0.41243185] Bias:  [0.37117865]
# Weights:  [0.40129173 0.41243185] Bias:  [0.39645972]
# Weights:  [0.3802734  0.39141352] Bias:  [0.37544139]
# MSE:  [0.32745765]
# Epoch 30
# -------------------------------------------------------------
# Weights:  [0.3802734  0.39141352] Bias:  [0.33789725]
# Weights:  [0.3802734  0.41848245] Bias:  [0.36496617]
# Weights:  [0.40574944 0.41848245] Bias:  [0.39044221]
# Weights:  [0.38428203 0.39701504] Bias:  [0.3689748]
# MSE:  [0.32521674]
# Epoch 31
# -------------------------------------------------------------
# Weights:  [0.38428203 0.39701504] Bias:  [0.33207732]
# Weights:  [0.38428203 0.4241058 ] Bias:  [0.35916809]
# Weights:  [0.40993702 0.4241058 ] Bias:  [0.38482308]
# Weights:  [0.38805043 0.40221921] Bias:  [0.36293649]
# MSE:  [0.32325348]
# Epoch 32
# -------------------------------------------------------------
# Weights:  [0.38805043 0.40221921] Bias:  [0.32664284]
# Weights:  [0.38805043 0.42933301] Bias:  [0.35375663]
# Weights:  [0.41386972 0.42933301] Bias:  [0.37957593]
# Weights:  [0.39159186 0.40705514] Bias:  [0.35729806]
# MSE:  [0.3215326]
# Epoch 33
# -------------------------------------------------------------
# Weights:  [0.39159186 0.40705514] Bias:  [0.32156826]
# Weights:  [0.39159186 0.4341928 ] Bias:  [0.34870592]
# Weights:  [0.41756208 0.4341928 ] Bias:  [0.37467614]
# Weights:  [0.39491898 0.4115497 ] Bias:  [0.35203304]
# MSE:  [0.32002342]
# Epoch 34
# -------------------------------------------------------------
# Weights:  [0.39491898 0.4115497 ] Bias:  [0.31682973]
# Weights:  [0.39491898 0.43871176] Bias:  [0.34399179]
# Weights:  [0.4210279  0.43871176] Bias:  [0.37010071]
# Weights:  [0.39804386 0.41572772] Bias:  [0.34711668]
# MSE:  [0.31869917]
# Epoch 35
# -------------------------------------------------------------
# Weights:  [0.39804386 0.41572772] Bias:  [0.31240501]
# Weights:  [0.39804386 0.44291445] Bias:  [0.33959174]
# Weights:  [0.4242803  0.44291445] Bias:  [0.36582818]
# Weights:  [0.40097801 0.41961215] Bias:  [0.34252588]
# MSE:  [0.31753656]
# Epoch 36
# -------------------------------------------------------------
# Weights:  [0.40097801 0.41961215] Bias:  [0.30827329]
# Weights:  [0.40097801 0.44682361] Bias:  [0.33548475]
# Weights:  [0.42733174 0.44682361] Bias:  [0.36183847]
# Weights:  [0.40373235 0.42322423] Bias:  [0.33823909]
# MSE:  [0.31651527]
# Epoch 37
# -------------------------------------------------------------
# Weights:  [0.40373235 0.42322423] Bias:  [0.30441518]
# Weights:  [0.40373235 0.45046029] Bias:  [0.33165124]
# Weights:  [0.43019399 0.45046029] Bias:  [0.35811288]
# Weights:  [0.40631728 0.42658357] Bias:  [0.33423617]
# MSE:  [0.31561757]
# Epoch 38
# -------------------------------------------------------------
# Weights:  [0.40631728 0.42658357] Bias:  [0.30081255]
# Weights:  [0.40631728 0.45384396] Bias:  [0.32807294]
# Weights:  [0.43287826 0.45384396] Bias:  [0.35463392]
# Weights:  [0.40874264 0.42970834] Bias:  [0.3304983]
# MSE:  [0.31482803]
# Epoch 39
# -------------------------------------------------------------
# Weights:  [0.40874264 0.42970834] Bias:  [0.29744847]
# Weights:  [0.40874264 0.45699266] Bias:  [0.32473279]
# Weights:  [0.4353951  0.45699266] Bias:  [0.35138525]
# Weights:  [0.4110178  0.43261536] Bias:  [0.32700795]
# MSE:  [0.31413316]
# Epoch 40
# -------------------------------------------------------------
# Weights:  [0.4110178  0.43261536] Bias:  [0.29430715]
# Weights:  [0.4110178  0.45992311] Bias:  [0.3216149]
# Weights:  [0.43775453 0.45992311] Bias:  [0.34835163]
# Weights:  [0.4131516  0.43532018] Bias:  [0.3237487]
# MSE:  [0.31352119]
# Epoch 41
# -------------------------------------------------------------
# Weights:  [0.4131516  0.43532018] Bias:  [0.29137383]
# Weights:  [0.4131516  0.46265078] Bias:  [0.31870443]
# Weights:  [0.439966   0.46265078] Bias:  [0.34551883]
# Weights:  [0.41515244 0.43783722] Bias:  [0.32070527]
# MSE:  [0.31298185]
# Epoch 42
# -------------------------------------------------------------
# Weights:  [0.41515244 0.43783722] Bias:  [0.28863474]
# Weights:  [0.41515244 0.46519003] Bias:  [0.31598754]
# Weights:  [0.44203844 0.46519003] Bias:  [0.34287355]
# Weights:  [0.41702824 0.44017982] Bias:  [0.31786335]
# MSE:  [0.31250618]
# Epoch 43
# -------------------------------------------------------------
# Weights:  [0.41702824 0.44017982] Bias:  [0.28607701]
# Weights:  [0.41702824 0.46755414] Bias:  [0.31345133]
# Weights:  [0.44398028 0.46755414] Bias:  [0.34040337]
# Weights:  [0.4187865  0.44236036] Bias:  [0.31520959]
# MSE:  [0.31208634]
# Epoch 44
# -------------------------------------------------------------
# Weights:  [0.4187865  0.44236036] Bias:  [0.28368863]
# Weights:  [0.4187865  0.46975546] Bias:  [0.31108373]
# Weights:  [0.44579948 0.46975546] Bias:  [0.33809671]
# Weights:  [0.42043431 0.4443903 ] Bias:  [0.31273154]
# MSE:  [0.31171549]
# Epoch 45
# -------------------------------------------------------------
# Weights:  [0.42043431 0.4443903 ] Bias:  [0.28145839]
# Weights:  [0.42043431 0.47180543] Bias:  [0.30887352]
# Weights:  [0.44750353 0.47180543] Bias:  [0.33594274]
# Weights:  [0.42197836 0.44628026] Bias:  [0.31041757]
# MSE:  [0.31138764]
# Epoch 46
# -------------------------------------------------------------
# Weights:  [0.42197836 0.44628026] Bias:  [0.27937581]
# Weights:  [0.42197836 0.47371465] Bias:  [0.3068102]
# Weights:  [0.4490995  0.47371465] Bias:  [0.33393135]
# Weights:  [0.42342495 0.4480401 ] Bias:  [0.3082568]
# MSE:  [0.31109755]
# Epoch 47
# -------------------------------------------------------------
# Weights:  [0.42342495 0.4480401 ] Bias:  [0.27743112]
# Weights:  [0.42342495 0.47549298] Bias:  [0.304884]
# Weights:  [0.45059406 0.47549298] Bias:  [0.3320531]
# Weights:  [0.42478005 0.44967897] Bias:  [0.30623909]
# MSE:  [0.31084066]
# Epoch 48
# -------------------------------------------------------------
# Weights:  [0.42478005 0.44967897] Bias:  [0.27561518]
# Weights:  [0.42478005 0.47714955] Bias:  [0.30308576]
# Weights:  [0.45199346 0.47714955] Bias:  [0.33029918]
# Weights:  [0.42604924 0.45120533] Bias:  [0.30435496]
# MSE:  [0.31061296]
# Epoch 49
# -------------------------------------------------------------
# Weights:  [0.42604924 0.45120533] Bias:  [0.27391947]
# Weights:  [0.42604924 0.47869285] Bias:  [0.30140699]
# Weights:  [0.45330362 0.47869285] Bias:  [0.32866136]
# Weights:  [0.42723784 0.45262707] Bias:  [0.30259558]
# MSE:  [0.31041093]
# Epoch 50
# -------------------------------------------------------------
# Weights:  [0.42723784 0.45262707] Bias:  [0.27233602]
# Weights:  [0.42723784 0.48013076] Bias:  [0.29983971]
# Weights:  [0.45453008 0.48013076] Bias:  [0.32713196]
# Weights:  [0.4283508  0.45395148] Bias:  [0.30095268]
# MSE:  [0.31023152]
# Epoch 51
# -------------------------------------------------------------
# Weights:  [0.4283508  0.45395148] Bias:  [0.27085741]
# Weights:  [0.4283508  0.48147059] Bias:  [0.29837652]
# Weights:  [0.45567807 0.48147059] Bias:  [0.32570379]
# Weights:  [0.42939283 0.45518535] Bias:  [0.29941854]
# MSE:  [0.31007203]
# Epoch 52
# -------------------------------------------------------------
# Weights:  [0.42939283 0.45518535] Bias:  [0.26947669]
# Weights:  [0.42939283 0.48271914] Bias:  [0.29701049]
# Weights:  [0.45675249 0.48271914] Bias:  [0.32437016]
# Weights:  [0.43036832 0.45633496] Bias:  [0.29798598]
# MSE:  [0.3099301]
# Epoch 53
# -------------------------------------------------------------
# Weights:  [0.43036832 0.45633496] Bias:  [0.26818738]
# Weights:  [0.43036832 0.48388273] Bias:  [0.29573514]
# Weights:  [0.45775797 0.48388273] Bias:  [0.3231248]
# Weights:  [0.43128142 0.45740618] Bias:  [0.29664825]
# MSE:  [0.30980367]
# Epoch 54
# -------------------------------------------------------------
# Weights:  [0.43128142 0.45740618] Bias:  [0.26698342]
# Weights:  [0.43128142 0.48496722] Bias:  [0.29454446]
# Weights:  [0.45869883 0.48496722] Bias:  [0.32196188]
# Weights:  [0.43213604 0.45840443] Bias:  [0.29539908]
# MSE:  [0.30969092]
# Epoch 55
# -------------------------------------------------------------
# Weights:  [0.43213604 0.45840443] Bias:  [0.26585917]
# Weights:  [0.43213604 0.48597807] Bias:  [0.29343281]
# Weights:  [0.45957915 0.48597807] Bias:  [0.32087593]
# Weights:  [0.43293584 0.45933475] Bias:  [0.29423261]
# MSE:  [0.30959026]
# Epoch 56
# -------------------------------------------------------------
# Weights:  [0.43293584 0.45933475] Bias:  [0.26480935]
# Weights:  [0.43293584 0.48692034] Bias:  [0.29239494]
# Weights:  [0.46040276 0.48692034] Bias:  [0.31986186]
# Weights:  [0.43368426 0.46020184] Bias:  [0.29314337]
# MSE:  [0.30950029]

# %% [markdown]
# - Predict outputs from neuron after weight adjustment

# %%
threshold = 0.5 ;
predicted_outputs = np.zeros(len(inputs)) ;
for i in range(len(inputs)):
    predicted_outputs[i] = np.dot(weights, inputs[i]) + bias ;
    if predicted_outputs[i] > threshold:
        predicted_outputs[i] = 1 ;
    else:
        predicted_outputs[i] = 0 ;
    
print('Predicted outputs: ', outputs) ;
# Out:
# Predicted outputs:  [0. 1. 1. 1.]
