# %% [markdown]
# # Adaline Learning for AND Neuron

# %%
import numpy as np ;

# %% [markdown]
# - Set up inputs and outputs of AND gate for training the neuron

# %%
inputs = [[0,0], [0,1], [1,0], [1,1]] ;
print('Inputs: ', inputs) ;
# Out:
# Inputs:  [[0, 0], [0, 1], [1, 0], [1, 1]]

# %%
outputs = np.zeros(len(inputs)) ;
for i in range(len(inputs)):
    if inputs[i][0] == 1 and inputs[i][1] == 1:
        outputs[i] = 1 ;
    else:
        outputs[i] = 0 ;
        
print('Target outputs: ', outputs) ;
# Out:
# Target outputs:  [0. 0. 0. 1.]

# %% [markdown]
# - Initialize weights to random values and select a learning rate

# %%
rate = 0.1 ;
tolerance = 0.0001 ;
np.random.seed(123) ;
weights = np.random.randn(2) ;
print('Initial weights: ', weights) ;
# Out:
# Initial weights:  [-1.0856306   0.99734545]

# %%
bias = np.random.randn(1) ;
print('Initial Bias: ', bias) ;
# Out:
# Initial Bias:  [0.2829785]

# %% [markdown]
# - Update the bias and weights using delta rule and stop the training in case of largest weight change is less than the specified tolerance

# %%
j = 0 ;
switch = True ;
prev_ms_error = 0 ;
while switch:
    print('Epoch', (j+1)) ;
    print('-------------------------------------------------------------')
    ms_error = 0 ;
    for i in range(len(inputs)):
        u = np.dot(inputs[i], weights) + bias ;
        error = outputs[i] - u ;
        weights += rate * error * inputs[i] ;
        bias += rate * error ;
        ms_error += np.square(error) ;
        print('Weights: ', weights, 'Bias: ', bias) ;
    if np.abs(ms_error - prev_ms_error) < tolerance:
        switch = False ;
    prev_ms_error = ms_error ;
    print('MSE: ', ms_error) ;
    j += 1 ;
# Out:
# Epoch 1
# -------------------------------------------------------------
# Weights:  [-1.0856306   0.99734545] Bias:  [0.25468065]
# Weights:  [-1.0856306   0.87214284] Bias:  [0.12947804]
# Weights:  [-0.99001535  0.87214284] Bias:  [0.2250933]
# Weights:  [-0.90073743  0.96142076] Bias:  [0.31437122]
# MSE:  [3.35892863]
# Epoch 2
# -------------------------------------------------------------
# Weights:  [-0.90073743  0.96142076] Bias:  [0.2829341]
# Weights:  [-0.90073743  0.83698527] Bias:  [0.15849861]
# Weights:  [-0.82651354  0.83698527] Bias:  [0.23272249]
# Weights:  [-0.75083297  0.91266585] Bias:  [0.30840307]
# MSE:  [2.77092171]
# Epoch 3
# -------------------------------------------------------------
# Weights:  [-0.75083297  0.91266585] Bias:  [0.27756276]
# Weights:  [-0.75083297  0.79364299] Bias:  [0.1585399]
# Weights:  [-0.69160366  0.79364299] Bias:  [0.21776921]
# Weights:  [-0.62358451  0.86166214] Bias:  [0.28578835]
# MSE:  [2.32522811]
# Epoch 4
# -------------------------------------------------------------
# Weights:  [-0.62358451  0.86166214] Bias:  [0.25720952]
# Weights:  [-0.62358451  0.74977497] Bias:  [0.14532235]
# Weights:  [-0.5757583   0.74977497] Bias:  [0.19314857]
# Weights:  [-0.51247482  0.81305845] Bias:  [0.25643204]
# MSE:  [1.96276329]
# Epoch 5
# -------------------------------------------------------------
# Weights:  [-0.51247482  0.81305845] Bias:  [0.23078884]
# Weights:  [-0.51247482  0.70867372] Bias:  [0.12640411]
# Weights:  [-0.47386775  0.70867372] Bias:  [0.16501118]
# Weights:  [-0.41384947  0.768692  ] Bias:  [0.22502947]
# MSE:  [1.6646446]
# Epoch 6
# -------------------------------------------------------------
# Weights:  [-0.41384947  0.768692  ] Bias:  [0.20252652]
# Weights:  [-0.41384947  0.67157015] Bias:  [0.10540467]
# Weights:  [-0.38300499  0.67157015] Bias:  [0.13624915]
# Weights:  [-0.32548642  0.72908872] Bias:  [0.19376772]
# MSE:  [1.41988045]
# Epoch 7
# -------------------------------------------------------------
# Weights:  [-0.32548642  0.72908872] Bias:  [0.17439095]
# Weights:  [-0.32548642  0.63874075] Bias:  [0.08404298]
# Weights:  [-0.30134207  0.63874075] Bias:  [0.10818732]
# Weights:  [-0.24590067  0.69418215] Bias:  [0.16362872]
# MSE:  [1.21949125]
# Epoch 8
# -------------------------------------------------------------
# Weights:  [-0.24590067  0.69418215] Bias:  [0.14726585]
# Weights:  [-0.24590067  0.61003735] Bias:  [0.06312105]
# Weights:  [-0.22762271  0.61003735] Bias:  [0.08139901]
# Weights:  [-0.17400408  0.66365599] Bias:  [0.13501765]
# MSE:  [1.05571329]
# Epoch 9
# -------------------------------------------------------------
# Weights:  [-0.17400408  0.66365599] Bias:  [0.12151588]
# Weights:  [-0.17400408  0.5851388 ] Bias:  [0.0429987]
# Weights:  [-0.16090354  0.5851388 ] Bias:  [0.05609923]
# Weights:  [-0.10893699  0.63710535] Bias:  [0.10806578]
# MSE:  [0.92193928]
# Epoch 10
# -------------------------------------------------------------
# Weights:  [-0.10893699  0.63710535] Bias:  [0.09725921]
# Weights:  [-0.10893699  0.56366889] Bias:  [0.02382275]
# Weights:  [-0.10042556  0.56366889] Bias:  [0.03233417]
# Weights:  [-0.04998331  0.61411114] Bias:  [0.08277642]
# MSE:  [0.812656]
# Epoch 11
# -------------------------------------------------------------
# Weights:  [-0.04998331  0.61411114] Bias:  [0.07449878]
# Weights:  [-0.04998331  0.54525015] Bias:  [0.00563779]
# Weights:  [-0.04554876  0.54525015] Bias:  [0.01007234]
# Weights:  [0.00347387 0.59427278] Bias:  [0.05909497]
# MSE:  [0.72332389]
# Epoch 12
# -------------------------------------------------------------
# Weights:  [0.00347387 0.59427278] Bias:  [0.05318547]
# Weights:  [0.00347387 0.52952695] Bias:  [-0.01156035]
# Weights:  [0.00428251 0.52952695] Bias:  [-0.01075171]
# Weights:  [0.05197674 0.57722118] Bias:  [0.03694252]
# MSE:  [0.65023369]
# Epoch 13
# -------------------------------------------------------------
# Weights:  [0.05197674 0.57722118] Bias:  [0.03324827]
# Weights:  [0.05197674 0.51617423] Bias:  [-0.02779868]
# Weights:  [0.04955893 0.51617423] Bias:  [-0.03021648]
# Weights:  [0.09600726 0.56262256] Bias:  [0.01623185]
# MSE:  [0.59036702]
# Epoch 14
# -------------------------------------------------------------
# Weights:  [0.09600726 0.56262256] Bias:  [0.01460866]
# Weights:  [0.09600726 0.50489944] Bias:  [-0.04311446]
# Weights:  [0.09071798 0.50489944] Bias:  [-0.04840374]
# Weights:  [0.13599661 0.55017807] Bias:  [-0.00312511]
# MSE:  [0.54127246]
# Epoch 15
# -------------------------------------------------------------
# Weights:  [0.13599661 0.55017807] Bias:  [-0.0028126]
# Weights:  [0.13599661 0.49544153] Bias:  [-0.05754915]
# Weights:  [0.12815187 0.49544153] Bias:  [-0.06539389]
# Weights:  [0.17233192 0.53962158] Bias:  [-0.02121384]
# MSE:  [0.50096042]
# Epoch 16
# -------------------------------------------------------------
# Weights:  [0.17233192 0.53962158] Bias:  [-0.01909246]
# Weights:  [0.17233192 0.48756866] Bias:  [-0.07114537]
# Weights:  [0.16221326 0.48756866] Bias:  [-0.08126402]
# Weights:  [0.20536147 0.53071687] Bias:  [-0.03811581]
# MSE:  [0.46781611]
# Epoch 17
# -------------------------------------------------------------
# Weights:  [0.20536147 0.53071687] Bias:  [-0.03430423]
# Weights:  [0.20536147 0.48107561] Bias:  [-0.0839455]
# Weights:  [0.19321988 0.48107561] Bias:  [-0.09608709]
# Weights:  [0.23539904 0.52325477] Bias:  [-0.05390793]
# MSE:  [0.44052833]
# Epoch 18
# -------------------------------------------------------------
# Weights:  [0.23539904 0.52325477] Bias:  [-0.04851714]
# Weights:  [0.23539904 0.47578101] Bias:  [-0.0959909]
# Weights:  [0.22145822 0.47578101] Bias:  [-0.10993172]
# Weights:  [0.26272747 0.51705026] Bias:  [-0.06866247]
# MSE:  [0.4180316]
# Epoch 19
# -------------------------------------------------------------
# Weights:  [0.26272747 0.51705026] Bias:  [-0.06179622]
# Weights:  [0.26272747 0.47152485] Bias:  [-0.10732162]
# Weights:  [0.24718689 0.47152485] Bias:  [-0.12286221]
# Weights:  [0.28760193 0.5119399 ] Bias:  [-0.08244716]
# MSE:  [0.39945935]
# Epoch 20
# -------------------------------------------------------------
# Weights:  [0.28760193 0.5119399 ] Bias:  [-0.07420245]
# Weights:  [0.28760193 0.46816615] Bias:  [-0.11797619]
# Weights:  [0.27063936 0.46816615] Bias:  [-0.13493877]
# Weights:  [0.31025268 0.50777948] Bias:  [-0.09532544]
# MSE:  [0.38410606]
# Epoch 21
# -------------------------------------------------------------
# Weights:  [0.31025268 0.50777948] Bias:  [-0.0857929]
# Weights:  [0.31025268 0.46558082] Bias:  [-0.12799155]
# Weights:  [0.29202657 0.46558082] Bias:  [-0.14621767]
# Weights:  [0.3308876  0.50444185] Bias:  [-0.10735664]
# MSE:  [0.37139668]
# Epoch 22
# -------------------------------------------------------------
# Weights:  [0.3308876  0.50444185] Bias:  [-0.09662098]
# Weights:  [0.3308876  0.46365976] Bias:  [-0.13740306]
# Weights:  [0.31153915 0.46365976] Bias:  [-0.15675152]
# Weights:  [0.34969441 0.50181502] Bias:  [-0.11859626]
# MSE:  [0.36086197]
# Epoch 23
# -------------------------------------------------------------
# Weights:  [0.34969441 0.50181502] Bias:  [-0.10673663]
# Weights:  [0.34969441 0.46230718] Bias:  [-0.14624447]
# Weights:  [0.32934941 0.46230718] Bias:  [-0.16658946]
# Weights:  [0.3668427  0.49980047] Bias:  [-0.12909618]
# MSE:  [0.35211854]
# Epoch 24
# -------------------------------------------------------------
# Weights:  [0.3668427  0.49980047] Bias:  [-0.11618656]
# Weights:  [0.3668427  0.46143908] Bias:  [-0.15454795]
# Weights:  [0.34561322 0.46143908] Bias:  [-0.17577743]
# Weights:  [0.38248574 0.49831159] Bias:  [-0.13890491]
# MSE:  [0.34485273]
# Epoch 25
# -------------------------------------------------------------
# Weights:  [0.38248574 0.49831159] Bias:  [-0.12501442]
# Weights:  [0.38248574 0.46098187] Bias:  [-0.16234414]
# Weights:  [0.36047158 0.46098187] Bias:  [-0.1843583]
# Weights:  [0.39676206 0.49727236] Bias:  [-0.14806781]
# MSE:  [0.3388076]
# Epoch 26
# -------------------------------------------------------------
# Weights:  [0.39676206 0.49727236] Bias:  [-0.13326103]
# Weights:  [0.39676206 0.46087123] Bias:  [-0.16966216]
# Weights:  [0.37405207 0.46087123] Bias:  [-0.19237215]
# Weights:  [0.40979696 0.49661611] Bias:  [-0.15662727]
# MSE:  [0.33377237]
# Epoch 27
# -------------------------------------------------------------
# Weights:  [0.40979696 0.49661611] Bias:  [-0.14096454]
# Weights:  [0.40979696 0.46105095] Bias:  [-0.1765297]
# Weights:  [0.38647023 0.46105095] Bias:  [-0.19985642]
# Weights:  [0.42170376 0.49628448] Bias:  [-0.1646229]
# MSE:  [0.32957387]
# Epoch 28
# -------------------------------------------------------------
# Weights:  [0.42170376 0.49628448] Bias:  [-0.14816061]
# Weights:  [0.42170376 0.46147209] Bias:  [-0.182973]
# Weights:  [0.39783068 0.46147209] Bias:  [-0.20684607]
# Weights:  [0.43258501 0.49622642] Bias:  [-0.17209174]
# MSE:  [0.32606965]
# Epoch 29
# -------------------------------------------------------------
# Weights:  [0.43258501 0.49622642] Bias:  [-0.15488257]
# Weights:  [0.43258501 0.46209204] Bias:  [-0.18901695]
# Weights:  [0.4082282  0.46209204] Bias:  [-0.21337376]
# Weights:  [0.44253356 0.49639739] Bias:  [-0.17906841]
# MSE:  [0.32314231]
# Epoch 30
# -------------------------------------------------------------
# Weights:  [0.44253356 0.49639739] Bias:  [-0.16116157]
# Weights:  [0.44253356 0.46287381] Bias:  [-0.19468515]
# Weights:  [0.41774872 0.46287381] Bias:  [-0.21946999]
# Weights:  [0.45163346 0.49675855] Bias:  [-0.18558524]
# MSE:  [0.32069499]
# Epoch 31
# -------------------------------------------------------------
# Weights:  [0.45163346 0.49675855] Bias:  [-0.16702672]
# Weights:  [0.45163346 0.46378537] Bias:  [-0.1999999]
# Weights:  [0.42647011 0.46378537] Bias:  [-0.22516326]
# Weights:  [0.45996088 0.49727615] Bias:  [-0.19167248]
# MSE:  [0.31864764]
# Epoch 32
# -------------------------------------------------------------
# Weights:  [0.45996088 0.49727615] Bias:  [-0.17250523]
# Weights:  [0.45996088 0.46479906] Bias:  [-0.20498232]
# Weights:  [0.43446303 0.46479906] Bias:  [-0.23048018]
# Weights:  [0.46758484 0.49792087] Bias:  [-0.19735837]
# MSE:  [0.31693398]
# Epoch 33
# -------------------------------------------------------------
# Weights:  [0.46758484 0.49792087] Bias:  [-0.17762253]
# Weights:  [0.46758484 0.46589103] Bias:  [-0.20965237]
# Weights:  [0.44179159 0.46589103] Bias:  [-0.23544561]
# Weights:  [0.47456789 0.49866733] Bias:  [-0.20266931]
# MSE:  [0.31549909]
# Epoch 34
# -------------------------------------------------------------
# Weights:  [0.47456789 0.49866733] Bias:  [-0.18240238]
# Weights:  [0.47456789 0.46704084] Bias:  [-0.21402888]
# Weights:  [0.44851399 0.46704084] Bias:  [-0.24008278]
# Weights:  [0.48096678 0.49949363] Bias:  [-0.20762998]
# MSE:  [0.31429734]
# Epoch 35
# -------------------------------------------------------------
# Weights:  [0.48096678 0.49949363] Bias:  [-0.18686699]
# Weights:  [0.48096678 0.46823097] Bias:  [-0.21812965]
# Weights:  [0.45468307 0.46823097] Bias:  [-0.24441336]
# Weights:  [0.486833  0.5003809] Bias:  [-0.21226343]
# MSE:  [0.31329081]
# Epoch 36
# -------------------------------------------------------------
# Weights:  [0.486833  0.5003809] Bias:  [-0.19103709]
# Weights:  [0.486833   0.46944652] Bias:  [-0.22197147]
# Weights:  [0.46034685 0.46944652] Bias:  [-0.24845762]
# Weights:  [0.49221328 0.50131294] Bias:  [-0.2165912]
# MSE:  [0.3124479]
# Epoch 37
# -------------------------------------------------------------
# Weights:  [0.49221328 0.50131294] Bias:  [-0.19493208]
# Weights:  [0.49221328 0.47067486] Bias:  [-0.22557016]
# Weights:  [0.46554896 0.47067486] Bias:  [-0.25223448]
# Weights:  [0.49715003 0.50227592] Bias:  [-0.22063341]
# MSE:  [0.31174226]
# Epoch 38
# -------------------------------------------------------------
# Weights:  [0.49715003 0.50227592] Bias:  [-0.19857007]
# Weights:  [0.49715003 0.47190534] Bias:  [-0.22894065]
# Weights:  [0.47032909 0.47190534] Bias:  [-0.25576159]
# Weights:  [0.50168181 0.50325805] Bias:  [-0.22440888]
# MSE:  [0.3111519]
# Epoch 39
# -------------------------------------------------------------
# Weights:  [0.50168181 0.50325805] Bias:  [-0.20196799]
# Weights:  [0.50168181 0.47312905] Bias:  [-0.23209699]
# Weights:  [0.47472333 0.47312905] Bias:  [-0.25905548]
# Weights:  [0.50584364 0.50424936] Bias:  [-0.22793517]
# MSE:  [0.31065839]
# Epoch 40
# -------------------------------------------------------------
# Weights:  [0.50584364 0.50424936] Bias:  [-0.20514165]
# Weights:  [0.50584364 0.47433859] Bias:  [-0.23505242]
# Weights:  [0.47876452 0.47433859] Bias:  [-0.26213154]
# Weights:  [0.50966736 0.50524143] Bias:  [-0.2312287]
# MSE:  [0.31024632]
# Epoch 41
# -------------------------------------------------------------
# Weights:  [0.50966736 0.50524143] Bias:  [-0.20810583]
# Weights:  [0.50966736 0.47552787] Bias:  [-0.23781939]
# Weights:  [0.48248256 0.47552787] Bias:  [-0.26500419]
# Weights:  [0.51318194 0.50622725] Bias:  [-0.23430481]
# MSE:  [0.30990276]
# Epoch 42
# -------------------------------------------------------------
# Weights:  [0.51318194 0.50622725] Bias:  [-0.21087433]
# Weights:  [0.51318194 0.47669195] Bias:  [-0.24040962]
# Weights:  [0.48590471 0.47669195] Bias:  [-0.26768685]
# Weights:  [0.51641373 0.50720097] Bias:  [-0.23717783]
# MSE:  [0.30961685]
# Epoch 43
# -------------------------------------------------------------
# Weights:  [0.51641373 0.50720097] Bias:  [-0.21346005]
# Weights:  [0.51641373 0.47782688] Bias:  [-0.24283414]
# Weights:  [0.48905577 0.47782688] Bias:  [-0.2701921]
# Weights:  [0.51938671 0.50815783] Bias:  [-0.23986116]
# MSE:  [0.30937947]
# Epoch 44
# -------------------------------------------------------------
# Weights:  [0.51938671 0.50815783] Bias:  [-0.21587504]
# Weights:  [0.51938671 0.47892955] Bias:  [-0.24510332]
# Weights:  [0.49195837 0.47892955] Bias:  [-0.27253166]
# Weights:  [0.52212275 0.50909392] Bias:  [-0.24236728]
# MSE:  [0.30918293]
# Epoch 45
# -------------------------------------------------------------
# Weights:  [0.52212275 0.50909392] Bias:  [-0.21813056]
# Weights:  [0.52212275 0.47999758] Bias:  [-0.24722689]
# Weights:  [0.49463316 0.47999758] Bias:  [-0.27471648]
# Weights:  [0.52464173 0.51000616] Bias:  [-0.2447079]
# MSE:  [0.30902076]
# Epoch 46
# -------------------------------------------------------------
# Weights:  [0.52464173 0.51000616] Bias:  [-0.22023711]
# Weights:  [0.52464173 0.48102925] Bias:  [-0.24921402]
# Weights:  [0.49709896 0.48102925] Bias:  [-0.27675679]
# Weights:  [0.52696182 0.51089211] Bias:  [-0.24689393]
# MSE:  [0.30888751]
# Epoch 47
# -------------------------------------------------------------
# Weights:  [0.52696182 0.51089211] Bias:  [-0.22220454]
# Weights:  [0.52696182 0.48202335] Bias:  [-0.2510733]
# Weights:  [0.49937297 0.48202335] Bias:  [-0.27866215]
# Weights:  [0.52909955 0.51174994] Bias:  [-0.24893557]
# MSE:  [0.30877858]
# Epoch 48
# -------------------------------------------------------------
# Weights:  [0.52909955 0.51174994] Bias:  [-0.22404201]
# Weights:  [0.52909955 0.48297914] Bias:  [-0.2528128]
# Weights:  [0.50147088 0.48297914] Bias:  [-0.28044148]
# Weights:  [0.53107002 0.51257829] Bias:  [-0.25084233]
# MSE:  [0.30869008]

# %% [markdown]
# - Predict outputs from neuron after weight adjustment

# %%
threshold = 0.5 ;
predicted_outputs = np.zeros(len(inputs)) ;
for i in range(len(inputs)):
    predicted_outputs[i] = np.dot(weights, inputs[i]) + bias ;
    if predicted_outputs[i] > threshold:
        predicted_outputs[i] = 1 ;
    else:
        predicted_outputs[i] = 0 ;
    
print('Predicted outputs: ', outputs) ;
